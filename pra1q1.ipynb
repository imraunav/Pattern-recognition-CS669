# %% [markdown]
# <a href="https://colab.research.google.com/github/imraunav/pattern-recognition/blob/main/pra1q1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
# !wget = "https://raw.githubusercontent.com/imraunav/pattern-recognition/main/Segment2_MelEnergy.csv"
# !wget = "https://raw.githubusercontent.com/imraunav/pattern-recognition/main/Segment3_MelEnergy.csv"
# !wget = "https://raw.githubusercontent.com/imraunav/pattern-recognition/main/Segment2_STEnergy.csv"
# !wget = "https://raw.githubusercontent.com/imraunav/pattern-recognition/main/Segment3_STEnergy.csv"
# !wget = "https://raw.githubusercontent.com/imraunav/pattern-recognition/main/Segment2_VAD_GT.csv"
# !wget = "https://raw.githubusercontent.com/imraunav/pattern-recognition/main/Segment3_VAD_GT.csv"
# Out:
# --2022-10-09 06:55:31--  http://=/
# Resolving = (=)... failed: Name or service not known.
# wget: unable to resolve host address ‘=’
# --2022-10-09 06:55:31--  https://raw.githubusercontent.com/imraunav/pattern-recognition/main/Segment2_MelEnergy.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3285 (3.2K) [text/plain]
# Saving to: ‘Segment2_MelEnergy.csv’
#
# Segment2_MelEnergy. 100%[===================>]   3.21K  --.-KB/s    in 0s
#
# 2022-10-09 06:55:31 (46.6 MB/s) - ‘Segment2_MelEnergy.csv’ saved [3285/3285]
#
# FINISHED --2022-10-09 06:55:31--
# Total wall clock time: 0.2s
# Downloaded: 1 files, 3.2K in 0s (46.6 MB/s)
# --2022-10-09 06:55:31--  http://=/
# Resolving = (=)... failed: Name or service not known.
# wget: unable to resolve host address ‘=’
# --2022-10-09 06:55:31--  https://raw.githubusercontent.com/imraunav/pattern-recognition/main/Segment3_MelEnergy.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3528 (3.4K) [text/plain]
# Saving to: ‘Segment3_MelEnergy.csv’
#
# Segment3_MelEnergy. 100%[===================>]   3.45K  --.-KB/s    in 0s
#
# 2022-10-09 06:55:32 (65.2 MB/s) - ‘Segment3_MelEnergy.csv’ saved [3528/3528]
#
# FINISHED --2022-10-09 06:55:32--
# Total wall clock time: 0.3s
# Downloaded: 1 files, 3.4K in 0s (65.2 MB/s)
# --2022-10-09 06:55:32--  http://=/
# Resolving = (=)... failed: Name or service not known.
# wget: unable to resolve host address ‘=’
# --2022-10-09 06:55:32--  https://raw.githubusercontent.com/imraunav/pattern-recognition/main/Segment2_STEnergy.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.111.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3288 (3.2K) [text/plain]
# Saving to: ‘Segment2_STEnergy.csv’
#
# Segment2_STEnergy.c 100%[===================>]   3.21K  --.-KB/s    in 0s
#
# 2022-10-09 06:55:32 (37.1 MB/s) - ‘Segment2_STEnergy.csv’ saved [3288/3288]
#
# FINISHED --2022-10-09 06:55:32--
# Total wall clock time: 0.2s
# Downloaded: 1 files, 3.2K in 0s (37.1 MB/s)
# --2022-10-09 06:55:32--  http://=/
# Resolving = (=)... failed: Name or service not known.
# wget: unable to resolve host address ‘=’
# --2022-10-09 06:55:32--  https://raw.githubusercontent.com/imraunav/pattern-recognition/main/Segment3_STEnergy.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3531 (3.4K) [text/plain]
# Saving to: ‘Segment3_STEnergy.csv’
#
# Segment3_STEnergy.c 100%[===================>]   3.45K  --.-KB/s    in 0s
#
# 2022-10-09 06:55:32 (56.0 MB/s) - ‘Segment3_STEnergy.csv’ saved [3531/3531]
#
# FINISHED --2022-10-09 06:55:32--
# Total wall clock time: 0.3s
# Downloaded: 1 files, 3.4K in 0s (56.0 MB/s)
# --2022-10-09 06:55:33--  http://=/
# Resolving = (=)... failed: Name or service not known.
# wget: unable to resolve host address ‘=’
# --2022-10-09 06:55:33--  https://raw.githubusercontent.com/imraunav/pattern-recognition/main/Segment2_VAD_GT.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 512 [text/plain]
# Saving to: ‘Segment2_VAD_GT.csv’
#
# Segment2_VAD_GT.csv 100%[===================>]     512  --.-KB/s    in 0s
#
# 2022-10-09 06:55:33 (39.0 MB/s) - ‘Segment2_VAD_GT.csv’ saved [512/512]
#
# FINISHED --2022-10-09 06:55:33--
# Total wall clock time: 0.2s
# Downloaded: 1 files, 512 in 0s (39.0 MB/s)
# --2022-10-09 06:55:33--  http://=/
# Resolving = (=)... failed: Name or service not known.
# wget: unable to resolve host address ‘=’
# --2022-10-09 06:55:33--  https://raw.githubusercontent.com/imraunav/pattern-recognition/main/Segment3_VAD_GT.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 550 [text/plain]
# Saving to: ‘Segment3_VAD_GT.csv’
#
# Segment3_VAD_GT.csv 100%[===================>]     550  --.-KB/s    in 0s
#
# 2022-10-09 06:55:33 (25.5 MB/s) - ‘Segment3_VAD_GT.csv’ saved [550/550]
#
# FINISHED --2022-10-09 06:55:33--
# Total wall clock time: 0.2s
# Downloaded: 1 files, 550 in 0s (25.5 MB/s)

# %% [markdown]
# # NOTE
# ### The classes given below are non-speech and speech. The following code uses the labels class 0 and class 1 to represent non-speech and speech

# %% [markdown]
# # Importing datasets

# %%
path = ''#use this as path for local file
#Getting feature vectors for training
with open(path + "Segment2_MelEnergy.csv", mode = 'r') as file:
    file_data = file.read()
    Mel_train_features = [float(data) for data in file_data.splitlines()]
# print(MelEnergy_data)

#Getting the ground truths
with open(path + 'Segment2_VAD_GT.csv', mode = 'r') as file:
    file_data = file.read()
    GT_train = [int(x) for x in file_data.splitlines()]
# print(GT)

#Testng features and ground truth data
with open(path + 'Segment3_MelEnergy.csv', mode = 'r') as file:
    file_data = file.read()
    Mel_test_features = [float(data) for data in file_data.splitlines()]
# print(Mel_test)

with open(path + 'Segment3_VAD_GT.csv', mode = 'r') as file:
    file_data = file.read()
    GT_test = [float(data) for data in file_data.splitlines()]
# print(GT_test)

#Getting STEnergy training features
with open(path + 'Segment2_STEnergy.csv', mode = 'r') as file:
    file_data = file.read()
    ST_train_features = [float(item) for item in file_data.splitlines()]
# print(ST_data)

#Getting testing STEnergy features
with open(path + 'Segment3_STEnergy.csv', mode = 'r') as file:
    file_data = file.read()
    ST_test_features = [float(item) for item in file_data.splitlines()]
# print(ST_test)

# %%
fig, ax = plt.subplots(2, 1)
ax[0].plot(Mel_train_features, label = 'Mel-filterbank energy', color = 'Blue')
ax[0].plot(ST_train_features, label = 'Short-time energy', color = 'Red')
ax[1].plot(Mel_test_features, label = 'Mel-filterbank energy', color = 'Blue')
ax[1].plot(ST_test_features, label = 'Short-time energy', color = 'Red')

ax[0].legend()
ax[1].legend()
ax[1].set_title('Testing data')
ax[0].set_title('Training data')

ax[0].set_xlabel('Frame instant')
ax[1].set_xlabel('Frame instant')

ax[0].set_ylabel('Energy value')
ax[1].set_ylabel('Energy value')
fig.tight_layout(rect=(0, 0, 2, 2))
# fig.savefig("plot_features.png", dpi = 750, bbox_inches = 'tight')
fig.show()

# %% [markdown]
# # Generalising some calculations

# %%
def confusion_mat(pred, actual):
    true_pos, false_pos, true_neg, false_neg = 0, 0, 0, 0
    for i in range(len(pred)):
        if pred[i] == 0 and actual[i] == 0:
            true_neg += 1
        if pred[i] == 0 and actual[i] == 1:
            false_neg += 1
        if pred[i] == 1 and actual[i] == 0:
            false_pos += 1
        if pred[i] == 1 and actual[i] == 1:
            true_pos += 1
    return true_pos, false_pos, true_neg, false_neg

# %%
def tp_fp_rate(pred, actual):
    tp, fp, tn, fn = confusion_mat(pred, actual)
    fpr = fp / (fp + tn)
    tpr = tp / (tp + fn)
    return tpr, fpr

# %%
def likelihood(x, mean, var):
    return (1/((2 * np.pi * var) ** 0.5)) * np.exp(- 0.5 * (x - mean) ** 2 / var)

# %%
def classifier(features, mean, var, priors):
  posteriors = []
  for x in features:
      likelihood_0 = likelihood(x, mean[0], var[0])
      likelihood_1 = likelihood(x, mean[1], var[1])
      evidence = likelihood_1 * priors[1] + likelihood_0 * priors[0]
      posterior_x = likelihood_1 * priors[1] / evidence
      posteriors.append(posterior_x)
  return posteriors

# %% [markdown]
# # Classifer based on MEL-Filterbank energy as features

# %%
#Some constants
class_0_features = [x for i, x in enumerate(Mel_train_features) if GT_train[i] == 0]
class_1_features = [x for i, x in enumerate(Mel_train_features) if GT_train[i] == 1]

means_mel = [np.mean(class_0_features), np.mean(class_1_features)]

var_mel = [np.var(class_0_features), np.var(class_1_features)]

priors = [len(class_0_features)/len(GT_train), len(class_1_features)/len(GT_train)]

# %%
class_0_dis = np.random.normal(means_mel[0], var_mel[0] ** 0.5, size = 10000)
class_1_dis = np.random.normal(means_mel[1], var_mel[1] ** 0.5, size = 10000)

print(f'Mean of class 0 features = {means_mel[0]}, Variance of class 0 features = {var_mel[0]}')
print(f'Mean of class 1 features = {means_mel[1]}, Variance of class 1 features = {var_mel[1]}')

_ = plt.hist([class_0_dis, class_1_dis], bins = 100, density = True, label = ['class 0', 'class 1'], histtype = 'step')

plt.ylabel('Probability density function')
plt.xlabel('Features as random variable')
plt.title('Probability density estimate of both classes')
plt.legend()
# plt.savefig("distribution_mel.png", dpi = 350)
plt.show()
# Out:
# Mean of class 0 features = 0.45865463603448275, Variance of class 0 features = 0.005185428144146614
# Mean of class 1 features = 0.6100466456738739, Variance of class 1 features = 0.022868307223842404

# %%
posteriors_mel = classifier(Mel_test_features, means_mel, var_mel, priors)

# %%
thresholds = sorted(np.random.uniform(0, 1, size = 1000))
# thresholds = np.linspace(0, 1, 1000)
x_roc_mel = []
y_roc_mel = []
for p_star in thresholds:
    classified = [1 if p > p_star else 0 for p in posteriors_mel]
    tpr, fpr = tp_fp_rate(classified, GT_test)
    x_roc_mel.append(fpr)
    y_roc_mel.append(tpr)
    
plt.plot(x_roc_mel, y_roc_mel, label = 'Mel-Filterbank energy')
plt.plot([0, 1], [0, 1], color = 'green', linestyle = '--', label = 'Chance level')
plt.legend()
plt.title('Reciever operating charecteristics')
# plt.savefig('roc_mel', dpi = 350)
plt.show()

# %% [markdown]
# # Classifier based on Short-time energy as features

# %%
#Some constants
class_0_features = [x for i, x in enumerate(ST_train_features) if GT_train[i] == 0]
class_1_features = [x for i, x in enumerate(ST_train_features) if GT_train[i] == 1]

means_st = [np.mean(class_0_features), np.mean(class_1_features)]

vars_st = [np.var(class_0_features),  np.var(class_1_features)]

# %%
class_0_dis = np.random.normal(means_st[0], vars_st[0] ** 0.5, size = 10000)
class_1_dis = np.random.normal(means_st[1], vars_st[1] ** 0.5, size = 10000)

print(f'Mean of class 0 features = {means_st[0]}, Variance of class 0 features = {vars_st[0]}')
print(f'Mean of class 1 features = {means_st[1]}, Variance of class 1 features = {vars_st[1]}')

_ = plt.hist([class_0_dis, class_1_dis], bins = 100, density = True, label = ['class 0', 'class 1'], histtype = 'step')

plt.ylabel('Probability density function')
plt.xlabel('Features as random variable')
plt.title('Probability density estimate of both classes')
plt.legend()
# plt.savefig('distribution_ste', dpi = 350)
plt.show()
# Out:
# Mean of class 0 features = 0.053090674108275865, Variance of class 0 features = 0.0012944035189149682
# Mean of class 1 features = 0.12043432332432433, Variance of class 1 features = 0.027681259243278893

# %%
posteriors_st = classifier(ST_test_features, means_st, vars_st, priors)

# %%
thresholds = sorted(np.random.uniform(0, 1, size = 1000))
# thresholds = np.linspace(0, 1, 1000)
x_roc_st = []
y_roc_st = []
for p_star in thresholds:
    classified = [1 if p > p_star else 0 for p in posteriors_st]
    tpr, fpr = tp_fp_rate(classified, GT_test)
    x_roc_st.append(fpr)
    y_roc_st.append(tpr)
    
plt.plot(x_roc_st, y_roc_st, label = 'Short-time energy', color = 'orange')
plt.plot([0, 1], [0, 1], color = 'green', linestyle = '--', label = 'Chance level')
plt.legend()
plt.title('Reciever operating charecteristics')
# plt.savefig('roc_ste', dpi = 350)
plt.show()

# %% [markdown]
# # Conclusion (MEL vs ST)

# %%
plt.plot(x_roc_mel, y_roc_mel, label = 'Mel-filterbank energy')
plt.plot(x_roc_st, y_roc_st, label = 'Short-time energy')
plt.plot([0, 1], [0, 1], label = 'Chance level', linestyle = '--', color = 'Green')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.legend()
plt.title('Reciever operating charecteristics curve of classifer systems')
plt.tight_layout(rect = (0, 0, 2, 2))
# plt.savefig('conclusion', dpi = 500, bbox_inches = 'tight')
plt.show()

# %%
# from google.colab import files
# for fig in ("plot_features.png", "distribution_mel.png", 'roc_mel.png', 'distribution_ste.png', 'roc_ste.png', 'conclusion.png'):
#   files.download(fig)
